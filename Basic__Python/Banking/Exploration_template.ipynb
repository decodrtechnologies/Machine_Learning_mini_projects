# %%
#List to store the account_holder_name
#Empty Dictionary to store the details
'''Key is name
   Value is Account Balance, Contact Number'''
#Password to access admin
#Self made
'''Function to implement admin role'''
def admin(password):
    #check for password
    #if password not match return with message that password not match
    #List of Choices
    '''1. Name of all Account_Holder
       2. Account Balance
       3. Modify Balance
       4. Modify Contact
       5. Add details
       6. Exit'''
    #Iterate till admin want to exit
        
        #Condition for choice==1
            #If no account_details have been added by checking the length of the list
                #print the message that no details found
            #Else 
                #print the name of all account holder with from the list

        
        #Condition for choice==2

            #If no account_details have been added by checking the length of the list
                #print the message that no details found
            #Else 
                #take input of the name of account_holder
                #if name not found in dictionary
                    #print The name of Account Holder not exist
                #else 
                    #print the account balance, that is 0th index of dictinary with key as name
        
        
        #Condition for choice==3
 
            #take input of the name of account_holder
            #if name(key) not in our dictionary
                #print The name of Account Holder not exist
            #else
                #take input of new balance
                #update the 0th index of name key
                #provide the choice whether to see the changes or continue 
                
                       
        #Condition for choice==4
    
            #take input of the name of account_holder
            #if name(key) not in our dictionary
                #print The name of Account Holder not exist
            #else
                #take input of new contact number
                #update the 1st index of name key
                #provide the choice whether to see the changes or continue 
            
        
        #Condition for choice==5
           #take input of the name of account_holder
            #if name(key)  in our dictionary
                #print The name of Account Holder already exist
            #Else
                #take input of name,account_balance,contact_number
                #save the details in dictionary with key as name
                #value as list of two, i,e account_balance and contact_number
                #Print that details added
        
        #Condition for choice==6
            #break
        #Else
            #print wrong choice provided
        
        #list of choices

# %%
'''User Function to implement'''
def user(name):
    '''if name not in our record'''
        #print that name does not exist
        #return
        
    #List of choice for the user
    '''1. Account Balance
       2. Contact Details
       3. Exit'''
    #Iterate till user want to exit
        #Condition for choice==1
            #print the account balance, that is 0th index of dictinary with key as name
       
        #Condition for choice==2
            #print the contact details, that is 1st index of dictinary with key as name
        
        #Condition for choice==3
            #break
           
        #Else
            #print wrong choice provided
        #list of choices

# %%
'''Bank Function implement'''
def bank():
    #print welcome message
    #List of choice
    '''1. Admin
       2. User
       3. Exit'''
    #iterate till person want to exit
        
        #condition for choice==1
            #input the password
            #call admin function and parameter as input password
        
        #condition for choice==2
            #input the name
            #call user function and parameter as input name
        
        #Condition for choice==3
            #break
           
        #Else
            #print wrong choice provided
        #list of choices

# %%
#Calling Bank Function
